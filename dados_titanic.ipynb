# %%
import pandas as pd
import numpy as np

# %%
train_dataset = pd.read_csv('train.csv')
print(train_dataset.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(train_dataset['Age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
print(train_dataset.Sex)
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
print(train_dataset[['Sex','Age','Fare']])
# Out:
#         Sex   Age     Fare
# 0      male  22.0   7.2500
# 1    female  38.0  71.2833
# 2    female  26.0   7.9250
# 3    female  35.0  53.1000
# 4      male  35.0   8.0500
# ..      ...   ...      ...
# 886    male  27.0  13.0000
# 887  female  19.0  30.0000
# 888  female   NaN  23.4500
# 889    male  26.0  30.0000
# 890    male  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
print(train_dataset.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(train_dataset[train_dataset.Sex == "female"])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df = pd.read_csv('train.csv')
train_df = train_df.drop('Name',axis=1)
print(train_df.head())
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
print(train_df.drop(0).head())
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
# 5            6         0       3    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
train_dataset['Embarked'] = "Porto"
print(train_dataset['Embarked'])
# Out:
# 0      Porto
# 1      Porto
# 2      Porto
# 3      Porto
# 4      Porto
#        ...
# 886    Porto
# 887    Porto
# 888    Porto
# 889    Porto
# 890    Porto
# Name: Embarked, Length: 891, dtype: object

# %%
train_df['Tamanho_Familia'] = train_df['SibSp'] + train_df['Parch']
print(train_df['Tamanho_Familia'])
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Name: Tamanho_Familia, Length: 891, dtype: int64

# %%
train_df['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
train_df.isnull().any()
# Out:
# PassengerId        False
# Survived           False
# Pclass             False
# Sex                False
# Age                 True
# SibSp              False
# Parch              False
# Ticket             False
# Fare               False
# Cabin               True
# Embarked            True
# Tamanho_Familia    False
# dtype: bool

# %%
print(train_df.dropna().head())
# Out:
#     PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch    Ticket  \
# 1             2         1       1  female  38.0      1      0  PC 17599
# 3             4         1       1  female  35.0      1      0    113803
# 6             7         0       1    male  54.0      0      0     17463
# 10           11         1       3  female   4.0      1      1   PP 9549
# 11           12         1       1  female  58.0      0      0    113783
#
#        Fare Cabin Embarked  Tamanho_Familia
# 1   71.2833   C85        C                1
# 3   53.1000  C123        S                1
# 6   51.8625   E46        S                0
# 10  16.7000    G6        S                2
# 11  26.5500  C103        S                0

# %%
filled_df = train_df
filled_df['Age'].fillna(filled_df['Age'].mean(), inplace=True)
filled_df['Embarked'].fillna(filled_df['Embarked'].mode()[0], inplace=True)

# %%
print(filled_df.isnull().any())
# Out:
# PassengerId        False
# Survived           False
# Pclass             False
# Sex                False
# Age                False
# SibSp              False
# Parch              False
# Ticket             False
# Fare               False
# Cabin               True
# Embarked           False
# Tamanho_Familia    False
# dtype: bool

# %%
print(train_df.duplicated("Embarked"))
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890     True
# Length: 891, dtype: bool

# %%
drop_duplicate_df = train_df.drop_duplicates(['Embarked'])
print(drop_duplicate_df)
# Out:
#    PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Ticket  \
# 0            1         0       3    male  22.000000      1      0  A/5 21171
# 1            2         1       1  female  38.000000      1      0   PC 17599
# 5            6         0       3    male  29.699118      0      0     330877
#
#       Fare Cabin Embarked  Tamanho_Familia
# 0   7.2500   NaN        S                1
# 1  71.2833   C85        C                1
# 5   8.4583   NaN        Q                0

# %%
train_df.mean()
# Out:
# PassengerId        446.000000
# Survived             0.383838
# Pclass               2.308642
# Age                 29.699118
# SibSp                0.523008
# Parch                0.381594
# Fare                32.204208
# Tamanho_Familia      0.904602
# dtype: float64

# %%
train_df.sum()
# Out:
# PassengerId                                                   397386
# Survived                                                         342
# Pclass                                                          2057
# Sex                malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                     26461.913824
# SibSp                                                            466
# Parch                                                            340
# Ticket             A/5 21171PC 17599STON/O2. 31012821138033734503...
# Fare                                                      28693.9493
# Embarked           SCSSSQSSSCSSSSSSQSSCSSQSSSCSQSCCQSCSCSSCSSCCQS...
# Tamanho_Familia                                                  806
# dtype: object

# %%
train_df.max(axis=1)
# Out:
# 0       22.0000
# 1       71.2833
# 2       26.0000
# 3       53.1000
# 4       35.0000
#          ...
# 886    887.0000
# 887    888.0000
# 888    889.0000
# 889    890.0000
# 890    891.0000
# Length: 891, dtype: float64

# %%
new_train_df = train_df.reindex(list(reversed(range(891))))
new_train_df.head()
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch  \
# 890          891         0       3    male  32.000000      0      0
# 889          890         1       1    male  26.000000      0      0
# 888          889         0       3  female  29.699118      1      2
# 887          888         1       1  female  19.000000      0      0
# 886          887         0       2    male  27.000000      0      0
#
#          Ticket   Fare Cabin Embarked  Tamanho_Familia
# 890      370376   7.75   NaN        Q                0
# 889      111369  30.00  C148        C                0
# 888  W./C. 6607  23.45   NaN        S                3
# 887      112053  30.00   B42        S                0
# 886      211536  13.00   NaN        S                0

# %%
new_train_df = new_train_df.sort_index()
new_train_df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Tamanho_Familia
# 0         A/5 21171   7.2500   NaN        S                1
# 1          PC 17599  71.2833   C85        C                1
# 2  STON/O2. 3101282   7.9250   NaN        S                0
# 3            113803  53.1000  C123        S                1
# 4            373450   8.0500   NaN        S                0

# %%
new_train_df.sort_index(ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch  \
# 890          891         0       3    male  32.000000      0      0
# 889          890         1       1    male  26.000000      0      0
# 888          889         0       3  female  29.699118      1      2
# 887          888         1       1  female  19.000000      0      0
# 886          887         0       2    male  27.000000      0      0
#
#          Ticket   Fare Cabin Embarked  Tamanho_Familia
# 890      370376   7.75   NaN        Q                0
# 889      111369  30.00  C148        C                0
# 888  W./C. 6607  23.45   NaN        S                3
# 887      112053  30.00   B42        S                0
# 886      211536  13.00   NaN        S                0

# %%
new_train_df.sort_values(by='Age').head()
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  Ticket  \
# 803          804         1       3    male  0.42      0      1    2625
# 755          756         1       2    male  0.67      1      1  250649
# 644          645         1       3  female  0.75      2      1    2666
# 469          470         1       3  female  0.75      2      1    2666
# 831          832         1       2    male  0.83      1      1   29106
#
#         Fare Cabin Embarked  Tamanho_Familia
# 803   8.5167   NaN        C                1
# 755  14.5000   NaN        S                2
# 644  19.2583   NaN        C                3
# 469  19.2583   NaN        C                3
# 831  18.7500   NaN        S                2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tabela = pd.pivot_table(data=train_df, values='PassengerId', index='Sex', columns='Survived', aggfunc='count')
print(tabela)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
bar_1 = tabela[0]

bar_2 = tabela[1]

x_pos = np.arange(len(bar_1))

first_bar = plt.bar(x_pos, bar_1, 0.5, color='b')
second_bar = plt.bar(x_pos, bar_2, 0.5, color='y', bottom=bar_1)

plt.xticks(x_pos+0.25, ('Female','Male'))

plt.show()

# %%
pie_female = tabela.loc['female']
pie_male = tabela.loc['male']


fig, eixos = plt.subplots(nrows=1, ncols=2, figsize=(8,4))

pie_1 = eixos[0].pie(pie_female, labels=['Não Sobreviveu','Sobreviveu'],
                    autopct='%1.1f%%', colors=['gold', 'lightskyblue'])

eixos[0].set_title('Female')

eixos[0].axis('equal')

pie_2 = eixos[1].pie(pie_male, labels=['Não Sobreviveu','Sobreviveu'], 
                    autopct='%1.1f%%', startangle=90, colors=['gold', 'lightskyblue'])
eixos[1].set_title('Male')
plt.axis('equal')

plt.subplots_adjust(wspace=1)
plt.show()

# %%
scatter_plot = plt.scatter(train_df['Age'], train_df['Fare'], alpha=0.5, 
                           c=train_df['Fare'])
plt.show()

# %%
train_df['Age'].fillna(train_df['Age'].mean(), inplace=True)
histogram_example = plt.hist(train_df['Age'], bins=15)
plt.show()

# %%
Prediction1=c1f1.predict(X_test)
RMSE_SGDR = np.sqrt(mean_squared_error(y_test, Prediction1))
R2_score_SGDR = r2_score(y_test,Prediction1)
Prediction2=C1f1.predict(X_train)
RMSE_SGDR_train = np.sqrt(mean_squared_error (y_train, Prediction2))
R2_score_SGDR_train = r2_score(y_train,Prediction2)
results_test = [RMSE_SGDR,R2_score_SGDR]
results_train = [RMSE_SGDR_train,R2_score_SGDR_train]
results = pd.DataFrame(data=[results_train,results_test],columns=['RHSE', 'Scorel'],index=["train’, test'])
results

# %%
Prediction1=c1f1.predict(X_test)
RMSE_SGDR = np.sqrt(mean_squared_error(y_test, Prediction1))
R2_score_SGDR = r2_score(y_test,Prediction1)
Prediction2=C1f1.predict(X_train)
RMSE_SGDR_train = np.sqrt(mean_squared_error (y_train, Prediction2))
R2_score_SGDR_train = r2_score(y_train,Prediction2)
results_test = [RMSE_SGDR,R2_score_SGDR]
results_train = [RMSE_SGDR_train,R2_score_SGDR_train]
results = pd.DataFrame(data=[results_train,results_test],columns=['RHSE', 'Scorel'],index=["train’, test'])
results

# %%
X_train, X_test, Y_train, Y_test = train_test_split(bookDetails, rating, test_size=0.30,random_state=123)
